# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn

# %%
np.random.seed(42)
real = pd.DataFrame(np.random.uniform(0.3,0.7,1000), columns=["prob of win"])
crowd = pd.DataFrame(np.random.uniform(0.3,0.7,1000), columns=["crowd odds given"])
df = pd.concat([real,crowd], axis = 1)
df
# Out:
#      prob of win  crowd odds given
# 0       0.449816          0.374053
# 1       0.680286          0.516760
# 2       0.592798          0.649178
# 3       0.539463          0.592890
# 4       0.362407          0.622624
# ..           ...               ...
# 995     0.336633          0.562782
# 996     0.666925          0.682646
# 997     0.354727          0.327583
# 998     0.680095          0.322822
# 999     0.478402          0.412875
#
# [1000 rows x 2 columns]

# %% [markdown]
# The Kelly Criterion is a mathematical formula used to determine the optimal size of a bet when the expected returns are known. The formula takes into account the probability of a favorable return, the ratio of average wins to average losses, and the win to loss ratio. The formula is **k% = bp–q/b**. The Kelly Criterion is used by investors and gamblers to decide how much money they should allocate to each investment or bet through a predetermined fraction of assets. The formula was developed by John Kelly.
# ![image-2.png](attachment:image-2.png)

# %%
def calculate_odds(data, crowd_col):
    american_odds = []
    riskwins = []

    for prob in data[crowd_col].to_list():
        if prob <= 0.5:
            american_odd = (100 - prob * 100) / prob
            risktowin = american_odd/100
        else:
            american_odd = (prob*100)/(prob-1)
            risktowin = ((american_odd-100)/american_odd)-1
        american_odds.append(american_odd)
        riskwins.append(risktowin)


    moneyline = pd.DataFrame(american_odds, columns=["american odds"])
    ratio = pd.DataFrame(riskwins, columns=["risk-1-to-win"])
    df = pd.concat([data, moneyline, ratio], axis = 1)

    p = df["prob of win"]
    q = 1 - df["prob of win"]
    b = df["risk-1-to-win"]

    #Using a half-kelly to reduce risk
    df['kelly criterion'] = ((b*p-q)/b)*.5

    return df

df = calculate_odds(df, "crowd odds given")

# %%
df.head()
# Out:
#    prob of win  crowd odds given  american odds  risk-1-to-win  \
# 0     0.449816          0.374053     167.341671       1.673417
# 1     0.680286          0.516760    -106.936674       0.935133
# 2     0.592798          0.649178    -185.045109       0.540409
# 3     0.539463          0.592890    -145.633831       0.686654
# 4     0.362407          0.622624    -164.988027       0.606105
#
#    kelly criterion
# 0         0.060519
# 1         0.169197
# 2        -0.080355
# 3        -0.065617
# 4        -0.344772

# %%
# this function creates a coin-flip (1,0) senario given outcome probabilities and appends it to a dataframe
def win_loss(data, col):
    probs = data[col].to_list()
    results = []
    for prob in probs:
    # if a team has a 0.6 chance of winning, this for loop
    # creates one number out of 0 or 1 with prob p 0.4 for 0 and 0.6 for 1
        winloss = np.random.choice(np.arange(0, 2), p=[1-prob, prob])
        results.append(winloss)
    data['win/loss'] = pd.DataFrame(results)

win_loss(df, "prob of win")

# %%
df.head()
# Out:
#    prob of win  crowd odds given  american odds  risk-1-to-win  \
# 0     0.449816          0.374053     167.341671       1.673417
# 1     0.680286          0.516760    -106.936674       0.935133
# 2     0.592798          0.649178    -185.045109       0.540409
# 3     0.539463          0.592890    -145.633831       0.686654
# 4     0.362407          0.622624    -164.988027       0.606105
#
#    kelly criterion  win/loss
# 0         0.060519         0
# 1         0.169197         0
# 2        -0.080355         1
# 3        -0.065617         0
# 4        -0.344772         0

# %%
df['win/loss'].value_counts()
# Out:
# 0    504
# 1    496
# Name: win/loss, dtype: int64

# %%
# calculates change in bankroll money over time and appends to dataframe
def calculate_bankroll(data, kelly_col):
    
    # filter dataset to only include positive kelly criterions
    df_bets = data[data[kelly_col] > 0].reset_index(drop=True)
    
    #simulate bankroll overtime
    starting_bankroll = 1000
    new_bankroll = 1000
    rolling_bankroll = []

    for i in np.asarray(df_bets):
        risk_to_win = i[3]
        kelly = i[4]
        winloss = i[5]

        if winloss == 1:
            new_bankroll = new_bankroll + new_bankroll*kelly*risk_to_win
        elif winloss == 0:
            new_bankroll = new_bankroll - new_bankroll*kelly

        rolling_bankroll.append(new_bankroll)
        
    # append new column to new dataframe
    df_bets = pd.concat([df_bets, pd.DataFrame(rolling_bankroll, columns=["rolling bankroll"])], axis = 1)
        
    return df_bets
    
df = calculate_bankroll(df, "kelly criterion")

# %%
df.head(10)
# Out:
#    prob of win  crowd odds given  american odds  risk-1-to-win  \
# 0     0.449816          0.374053     167.341671       1.673417
# 1     0.680286          0.516760    -106.936674       0.935133
# 2     0.646470          0.639678    -177.529744       0.563286
# 3     0.540446          0.399867     150.083025       1.500830
# 4     0.583229          0.495770     101.706442       1.017064
# 5     0.384936          0.315771     216.685469       2.166855
# 6     0.421697          0.372230     168.651003       1.686510
# 7     0.416492          0.313578     218.899525       2.188995
# 8     0.614070          0.489686     104.212626       1.042126
# 9     0.536966          0.427640     133.841445       1.338414
#
#    kelly criterion  win/loss  rolling bankroll
# 0         0.060519         0        939.481380
# 1         0.169197         0        780.523993
# 2         0.009425         1        784.667852
# 3         0.117123         0        692.765138
# 4         0.086725         1        753.870670
# 5         0.050542         0        715.768380
# 6         0.039399         0        687.567964
# 7         0.074964         1        800.394399
# 8         0.121871         0        702.849795
# 9         0.095504         0        635.724622

# %%
import matplotlib.pyplot as plt

plt.plot(range(1,len(df)+1), df["rolling bankroll"])

# %%
min(df["rolling bankroll"]), max(df["rolling bankroll"])
# Out:
# (529.8559200420468, 8793794738.065722)

# %%
df["win/loss"].value_counts()
# Out:
# 1    272
# 0    228
# Name: win/loss, dtype: int64

# %%
seeds = range(1,501)
number_of_games = 600

fig, ax = plt.subplots()

dictTest = {}
averages = []

min_bankroll = []
max_bankroll = []
mean_bankroll = []
final_acct_value = []

bankrupt_count = 0
success_count = 0
total_count = 0 

for s in seeds:
    
    #set seed
    np.random.seed(s)
    
    #create df
    real = pd.DataFrame(np.random.uniform(0.35,0.65,number_of_games), columns=["prob of win"])
    crowd = pd.DataFrame(np.random.uniform(0.35,0.65,number_of_games), columns=["crowd odds given"])
    df = pd.concat([real,crowd], axis = 1)
    
    #calculate kelly criterion
    df = calculate_odds(df, "crowd odds given")
    
    #simulate win/loss
    win_loss(df, "prob of win")

    #calculate bankroll change over time
    df = calculate_bankroll(df, "kelly criterion")
    
    #save min and max values for further analysis
    min_bankroll.append(int(min(df['rolling bankroll'])))
    max_bankroll.append(int(max(df['rolling bankroll'])))
    mean_bankroll.append(int(df['rolling bankroll'].mean()))
    final_acct_value.append(int(df.iloc[-1]["rolling bankroll"]))
    
    #count the total number of bankrupt and success accounts 
    if min(df["rolling bankroll"]) < 100:
        bankrupt_count += 1
    
    if max(df["rolling bankroll"]) >= 100000:
        success_count += 1
    
    total_count += 1 
    
    test2 = enumerate(df["rolling bankroll"].to_list())

    for i in test2:
    #     print(i[0])
        if i[0] in dictTest:
            dictTest[i[0]].append(int(i[1])) 
        else:
            dictTest[i[0]] = [int(i[1])]
            
    ax.plot(range(1,len(df)+1), df["rolling bankroll"], alpha=.35)
            
for key in dictTest.values():
    averages.append(np.mean(key))
    
ax.plot(range(1,len(df)+1), averages[:len(df)], 'b', alpha=1, lw=3, label="Average Amount")
ax.set_ylim(0,5000000)
ax.set_xlim(0,len(df)+1)
ax.set_ylabel("Dollar Amount in Millions")
ax.set_xlabel("Number of Games")
ax.set_title("Kelly Criterion Success")
ax.legend()
plt.show()

# %%
print(f"min value: {round(min(min_bankroll),2)}")
plt.hist(min_bankroll)
plt.show()
# Out:
# min value: 152

# %%
print("Half-Kelly")
print(f"min: {min(min_bankroll)}, max: {max(max_bankroll)}, mean: {int(np.mean(mean_bankroll))}")
print(f"Final amts min, max, mean: {min(final_acct_value)}, {max(final_acct_value)}, {int(np.mean(final_acct_value))}")
# Out:
# Half-Kelly
# min: 152, max: 1978614182, mean: 1555753
# Final amts min, max, mean: 1786, 1022926044, 11862402

# %%
len(averages)
# Out:
# 343

# %%
bankrupt_count, success_count, total_count
# Out:
# (0, 454, 500)

# %% [markdown]
# Of 500 randomly created accounts betting on a max of 343 games each, 0 went bankrupt (defined as having less than 100 dollars at any given time), whereas 454 accounts surpassed 100,000 dollars at some point.
#
# The overall mean value was $1,555,753.
#
# The average final account value was $11,862,402.
#
# Further analysis on the Kelly Criterion and it's betting applications could be done to assess the impact of casino odds advantages and real world data.

# %%
plt.plot(range(1, len(averages)+1), averages)

# %%
averages[-10:]
# Out:
# [8103112.333333333,
#  3499907.0,
#  3787077.0,
#  4358255.0,
#  4042057.0,
#  3916137.0,
#  3371775.0,
#  3452859.0,
#  3163094.0,
#  2818237.0]

# %%
import os
os.chdir(r'C:\Users\Sarah Pierce\Documents\betting data')
ml = pd.read_csv("538_ml.csv")

# %%
ml.head()
# Out:
#    Unnamed: 0        date  season  neutral playoff home_team away_team  \
# 0           0  2007-10-30    2008        0     NaN       SAS       POR
# 1           1  2007-10-30    2008        0     NaN       LAL       HOU
# 2           2  2007-10-30    2008        0     NaN       GSW       UTA
# 3           3  2007-10-31    2008        0     NaN       CLE       DAL
# 4           4  2007-10-31    2008        0     NaN       NOP       SAC
#
#    home_elo_prob  away_elo_prob  home_carm-elo_prob  away_carm-elo_prob  \
# 0       0.882229       0.117771                 NaN                 NaN
# 1       0.536006       0.463994                 NaN                 NaN
# 2       0.637471       0.362529                 NaN                 NaN
# 3       0.600327       0.399673                 NaN                 NaN
# 4       0.713491       0.286509                 NaN                 NaN
#
#    home_raptor_prob  away_raptor_prob  home_score  away_score  home_ml  \
# 0               NaN               NaN       106.0        97.0    -1400
# 1               NaN               NaN        93.0        95.0      190
# 2               NaN               NaN        96.0       117.0     -120
# 3               NaN               NaN        74.0        92.0      120
# 4               NaN               NaN       104.0        90.0     -525
#
#    away_ml
# 0      900
# 1     -230
# 2      100
# 3     -140
# 4      425

# %%
ml.loc[ml['home_score'] > ml["away_score"], 'team_w/l'] = "Home"
ml.loc[ml['home_score'] < ml["away_score"], 'team_w/l'] = "Away"
ml.head()
# Out:
#    Unnamed: 0        date  season  neutral playoff home_team away_team  \
# 0           0  2007-10-30    2008        0     NaN       SAS       POR
# 1           1  2007-10-30    2008        0     NaN       LAL       HOU
# 2           2  2007-10-30    2008        0     NaN       GSW       UTA
# 3           3  2007-10-31    2008        0     NaN       CLE       DAL
# 4           4  2007-10-31    2008        0     NaN       NOP       SAC
#
#    home_elo_prob  away_elo_prob  home_carm-elo_prob  away_carm-elo_prob  \
# 0       0.882229       0.117771                 NaN                 NaN
# 1       0.536006       0.463994                 NaN                 NaN
# 2       0.637471       0.362529                 NaN                 NaN
# 3       0.600327       0.399673                 NaN                 NaN
# 4       0.713491       0.286509                 NaN                 NaN
#
#    home_raptor_prob  away_raptor_prob  home_score  away_score  home_ml  \
# 0               NaN               NaN       106.0        97.0    -1400
# 1               NaN               NaN        93.0        95.0      190
# 2               NaN               NaN        96.0       117.0     -120
# 3               NaN               NaN        74.0        92.0      120
# 4               NaN               NaN       104.0        90.0     -525
#
#    away_ml team_w/l
# 0      900     Home
# 1     -230     Away
# 2      100     Away
# 3     -140     Away
# 4      425     Home

# %%
ml = ml[["date", 
         "season", 
         "playoff", 
         "home_team", 
         "away_team", 
         "home_score", 
         "away_score", 
         "home_ml", 
         "away_ml", 
         "team_w/l"]]
ml.head()
# Out:
#          date  season playoff home_team away_team  home_score  away_score  \
# 0  2007-10-30    2008     NaN       SAS       POR       106.0        97.0
# 1  2007-10-30    2008     NaN       LAL       HOU        93.0        95.0
# 2  2007-10-30    2008     NaN       GSW       UTA        96.0       117.0
# 3  2007-10-31    2008     NaN       CLE       DAL        74.0        92.0
# 4  2007-10-31    2008     NaN       NOP       SAC       104.0        90.0
#
#    home_ml  away_ml team_w/l
# 0    -1400      900     Home
# 1      190     -230     Away
# 2     -120      100     Away
# 3      120     -140     Away
# 4     -525      425     Home

# %%
ml.shape
# Out:
# (18412, 10)

# %%
def convert_odds_home(df, ml_column, home_away):
    implied_probability = []
    
    for odd in df[ml_column].to_list():
        if odd < 0:
            prob = -odd/(-odd+100)
        else:
            prob = 100/(odd+100)
        implied_probability.append(prob)
        
    probs = pd.DataFrame(implied_probability, columns=["implied_prob_"+home_away])
    df = pd.concat([df, probs], axis = 1)

    return df

ml = convert_odds_home(ml, "home_ml", "home")
ml = convert_odds_home(ml, "away_ml", "away")
ml.head()
# Out:
#          date  season playoff home_team away_team  home_score  away_score  \
# 0  2007-10-30    2008     NaN       SAS       POR       106.0        97.0
# 1  2007-10-30    2008     NaN       LAL       HOU        93.0        95.0
# 2  2007-10-30    2008     NaN       GSW       UTA        96.0       117.0
# 3  2007-10-31    2008     NaN       CLE       DAL        74.0        92.0
# 4  2007-10-31    2008     NaN       NOP       SAC       104.0        90.0
#
#    home_ml  away_ml team_w/l  implied_prob_home  implied_prob_away
# 0    -1400      900     Home           0.933333           0.100000
# 1      190     -230     Away           0.344828           0.696970
# 2     -120      100     Away           0.545455           0.500000
# 3      120     -140     Away           0.454545           0.583333
# 4     -525      425     Home           0.840000           0.190476

# %%
def bin_probs(df, implied_prob, increment):
    
    binned_probs = [] 
    
    for probs in df[implied_prob]:
        print(probs)
#         if prob > 0 and prob <= increment:                  #0-5
#             prob = increment/2                              #return 2.5
#         elif prob > increment and prob <= increment*2:      #5-10
#             prob = increment*3/2                            #return 7.5
#         elif prob > increment*2 and prob <= increment*3:    #10-15
#             prob = increment*5/2                            #return 12.5
#         elif prob > increment*3 and prob <= increment*4:    #15-20
#             prob = increment*7/2                            #return 17.5
#         elif prob > increment*4 and prob <= increment*5:    #20-25
#             prob = increment*9/2                            #return 22.5
#         elif prob > increment*5 and prob <= increment*6:    #25-30
#             prob = increment*11/2                           #return 27.5
#         elif prob > increment*6 and prob <= increment*7:    #30-35
#             prob = increment*13/2                           #return 32.5
#         elif prob > increment*7 and prob <= increment*8:    #35-40
#             prob = increment*15/2                           #return 37.5
#         elif prob > increment*8 and prob <= increment*9:    #40-45
#             prob = increment*17/2                            #return 42.5
#         elif prob > increment*9 and prob <= increment*10:    #45-50
#             prob = increment*19/2                            #return 47.5
#         elif prob > increment*10 and prob <= increment*11:    #50-55
#             prob = increment*21/2                            #return 52.5
#         elif prob > increment*11 and prob <= increment*12:    #55-60
#             prob = increment*23/2                           #return 57.5
#         elif prob > increment*12 and prob <= increment*13:    #60-65
#             prob = increment*25/2                           #return 62.5
#         elif prob > increment*13 and prob <= increment*14:    #65-70
#             prob = increment*27/2                           #return 67.5
#         elif prob > increment*14 and prob <= increment*15:    #70-75
#             prob = increment*29/2                            #return 72.5
#         elif prob > increment*15 and prob <= increment*16:    #75-80
#             prob = increment*31/2                            #return 77.5
#         elif prob > increment*16 and prob <= increment*17:    #80-85
#             prob = increment*33/2                            #return 82.5
#         elif prob > increment*17 and prob <= increment*18:    #85-90
#             prob = increment*35/2                           #return 87.5
#         elif prob > increment*18 and prob <= increment*19:    #90-95
#             prob = increment*37/2                           #return 92.5
#         elif prob > increment*19 and prob <= increment*20:    #95-100
#             prob = increment*39/2                           #return 97.5
        
#         binned_probs.append(prob)
        
#     probs_binned = pd.DataFrame(binned_probs, columns=["probs_binned_"+home_away])
#     df = pd.concat([df, probs_binned], axis = 1)

test = bin_probs(ml, "implied_prob_home", 0.05)
ml = bin_probs(ml, "implied_prob_away", 0.05)

test
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\SARAHP~1\AppData\Local\Temp/ipykernel_5512/3919797502.py in <module>
#      51 #     df = pd.concat([df, probs_binned], axis = 1)
#      52
# ---> 53 test = bin_probs(ml, "implied_prob_home", 0.05)
#      54 ml = bin_probs(ml, "implied_prob_away", 0.05)
#      55
#
# C:\Users\SARAHP~1\AppData\Local\Temp/ipykernel_5512/3919797502.py in bin_probs(df, implied_prob, increment)
#       3     binned_probs = []
#       4
# ----> 5     for probs in df[implied_prob]:
#       6         print(probs)
#       7 #         if prob > 0 and prob <= increment:                  #0-5
#
# TypeError: 'NoneType' object is not subscriptable
